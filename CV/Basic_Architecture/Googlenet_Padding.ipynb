# %% [markdown]
# https://stats.stackexchange.com/questions/247269/i-cant-understand-part-of-the-googlenet-incarnation-table

# %% [markdown]
# When Googlemap extracts featuremap from each layers, it utilizes asymmetrical padding

# %% [markdown]
# ![image.png](attachment:8f79a241-f325-411d-9547-2fdb9da26ed0.png)
